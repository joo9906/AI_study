# %% [markdown]
# # 좌표를 모델 인풋으로 바꾸기

# %%
import os
import re
import pandas as pd
import numpy as np
from pathlib import Path

from csv_to_npz import save_npz_sample_from_segment

# %%
# 경로 설정
project_path = '/home/j-j13a602/make_dataset'

# %%
# word_id, person_id로 추출할 csv 파일 찾기

def find_target_csv_file(file_name, target_word_ids, target_person_ids, video_type):

    if video_type == "crowd":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("FS")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("CROWD")[-1][:2])

    elif video_type == "real":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("WORD")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("REAL")[-1][:2])

    elif video_type == "syn":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("WORD")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("SYN")[-1][:2])

    # 현재 파일의 단어와 사람 번호가 있으면 변환 가능
    if current_word_id in target_word_ids and current_person_id in target_person_ids:
        print(f"파일명 '{file_name}' 변환 가능")
        return True
    else:
        print(f"파일명 '{file_name}' 에러")
        return False


def get_word_id_and_person_id(file_name, video_type):
    if video_type == "crowd":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("FS")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("CROWD")[-1][:2])

    elif video_type == "real":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("WORD")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("REAL")[-1][:2])

    elif video_type == "syn":
        # 현재 파일의 단어 번호
        current_word_id = int(file_name.split("WORD")[-1][:4])
        # 현재 파일의 사람 번호
        current_person_id = int(file_name.split("SYN")[-1][:2])

    return current_word_id, current_person_id

# %%
# 들어있는 csv 확인하기
annotation_dir = project_path + "/annotation"

annotation_dir_files = [
    os.path.join(annotation_dir, f)
    for f in os.listdir(annotation_dir)
    if f.lower().endswith(".csv") and re.search(r"real", f, re.IGNORECASE)
]

print("총 좌표 csv 개수:", len(annotation_dir_files))
print(annotation_dir_files[:3])
# Out:
# 총 좌표 csv 개수: 1500
# ['/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0749_REAL09_F.csv', '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0798_REAL09_F.csv', '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0572_REAL09_F.csv']

# %%
# 메타데이터 불러오기
real_detail_metadata = pd.read_csv(project_path + "/real_word_detail_metadata.csv", encoding="utf-8")

print(real_detail_metadata.shape)
real_detail_metadata.head(2)
# Out:
# (48000, 11)
#                  basename                                            mp4_url  \
# 0  NIA_SL_WORD0001_REAL01  https://blackolivevideo.blob.core.windows.net/...
# 1  NIA_SL_WORD0002_REAL01  https://blackolivevideo.blob.core.windows.net/...
#
#                        mp4_name  duration exported_on  word_start  word_end  \
# 0  NIA_SL_WORD0001_REAL01_F.mp4     4.867  2020/12/10       1.743     3.103
# 1  NIA_SL_WORD0002_REAL01_F.mp4     4.434  2020/12/10       1.831     3.361
#
#   word_name  word_id  person_id  video_annotated
# 0        고민        1          1             True
# 1        뻔뻔        2          1             True

# %%
# @title word에 있는 csv -> npz 파일 변경하기.

target_word_ids = list(range(1, 3001))
target_person_ids = list(range(1, 11))

completed_word_count = 0
error_word_files = []
real_npz_folder = project_path + "/npz" # Define the real_data folder path

for annotation_file in annotation_dir_files:
    # Construct the expected NPZ file path
    base_name = Path(annotation_file).stem
    expected_npz_path = os.path.join(real_npz_folder, f"{base_name}.npz")

    # Check if the NPZ file already exists
    if os.path.exists(expected_npz_path):
        print(f"NPZ 파일이 이미 존재합니다. 스킵: {expected_npz_path}")
        completed_word_count += 1 # Count existing files as completed
        continue # Skip to the next file

    # Check if the file name matches the target word and person IDs
    if find_target_csv_file(annotation_file, target_word_ids, target_person_ids, "real"):
        # If it matches, process the file
        target_ann_file = os.path.join(annotation_dir, annotation_file)
        target_word_id, target_person_id = get_word_id_and_person_id(annotation_file, "real")
        file_name, target_type = os.path.splitext(target_ann_file)

        try:
            out_file = save_npz_sample_from_segment(
                target_path=target_ann_file,
                target_type=target_type.strip("."),
                metadata=real_detail_metadata,
                out_dir=real_npz_folder, # Use the defined real_npz_folder
                label_id=target_word_id,
                use_buckets=True,
                FPS=30,
            )
            print("[SAVED]", out_file)
            completed_word_count += 1

        except Exception as e:
            # Check if out_file is defined before printing
            if 'out_file' in locals():
                print(f"[{e}] {out_file}")
            else:
                print(f"[{e}] Error processing {target_ann_file}")
                error_word_files.append(target_ann_file)
    else:
        print(f"파일명 '{annotation_file}' 는 타겟 word_id 또는 person_id에 해당하지 않습니다. 스킵.")


print(f"에러 파일 개수: {len(error_word_files)}")
print(f"변환 성공 파일 개수 (기존 파일 포함): {completed_word_count}")
# Out:
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0749_REAL09_F.csv' 변환 가능
# Word start time: 1.316s -> Start frame: 39
# Word end time: 2.905s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0749_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0798_REAL09_F.csv' 변환 가능
# Word start time: 1.992s -> Start frame: 60
# Word end time: 3.527s -> End frame: 106
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0798_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0572_REAL09_F.csv' 변환 가능
# Word start time: 1.371s -> Start frame: 41
# Word end time: 3.74s -> End frame: 112
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0572_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0963_REAL09_F.csv' 변환 가능
# Word start time: 2.192s -> Start frame: 66
# Word end time: 3.981s -> End frame: 119
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0963_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1465_REAL09_F.csv' 변환 가능
# Word start time: 1.392s -> Start frame: 42
# Word end time: 2.459s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1465_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0913_REAL09_F.csv' 변환 가능
# Word start time: 2.317s -> Start frame: 70
# Word end time: 3.139s -> End frame: 94
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0913_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0501_REAL09_F.csv' 변환 가능
# Word start time: 1.33s -> Start frame: 40
# Word end time: 3.027s -> End frame: 91
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0501_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1120_REAL09_F.csv' 변환 가능
# Word start time: 1.716s -> Start frame: 51
# Word end time: 2.748s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1120_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1035_REAL09_F.csv' 변환 가능
# Word start time: 1.312s -> Start frame: 39
# Word end time: 3.903s -> End frame: 117
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1035_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0825_REAL09_F.csv' 변환 가능
# Word start time: 1.419s -> Start frame: 43
# Word end time: 3.065s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0825_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0475_REAL09_F.csv' 변환 가능
# Word start time: 1.264s -> Start frame: 38
# Word end time: 2.864s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0475_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0437_REAL09_F.csv' 변환 가능
# Word start time: 1.402s -> Start frame: 42
# Word end time: 2.783s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0437_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1090_REAL09_F.csv' 변환 가능
# Word start time: 1.681s -> Start frame: 50
# Word end time: 3.655s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1090_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1485_REAL09_F.csv' 변환 가능
# Word start time: 1.184s -> Start frame: 36
# Word end time: 2.643s -> End frame: 79
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1485_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0483_REAL09_F.csv' 변환 가능
# Word start time: 1.305s -> Start frame: 39
# Word end time: 3.054s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0483_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0742_REAL09_F.csv' 변환 가능
# Word start time: 1.181s -> Start frame: 35
# Word end time: 2.804s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0742_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0762_REAL09_F.csv' 변환 가능
# Word start time: 1.06s -> Start frame: 32
# Word end time: 2.694s -> End frame: 81
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0762_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0001_REAL09_F.csv' 변환 가능
# Word start time: 3.427s -> Start frame: 103
# Word end time: 4.617s -> End frame: 139
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0001_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0981_REAL09_F.csv' 변환 가능
# Word start time: 2.704s -> Start frame: 81
# Word end time: 3.677s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0981_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0195_REAL09_F.csv' 변환 가능
# Word start time: 2.429s -> Start frame: 73
# Word end time: 4.036s -> End frame: 121
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0195_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1444_REAL09_F.csv' 변환 가능
# Word start time: 1.406s -> Start frame: 42
# Word end time: 2.535s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1444_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1182_REAL09_F.csv' 변환 가능
# Word start time: 1.361s -> Start frame: 41
# Word end time: 2.239s -> End frame: 67
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1182_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0950_REAL09_F.csv' 변환 가능
# Word start time: 2.224s -> Start frame: 67
# Word end time: 3.264s -> End frame: 98
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0950_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1236_REAL09_F.csv' 변환 가능
# Word start time: 1.494s -> Start frame: 45
# Word end time: 2.196s -> End frame: 66
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1236_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0926_REAL09_F.csv' 변환 가능
# Word start time: 2.197s -> Start frame: 66
# Word end time: 2.875s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0926_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0621_REAL09_F.csv' 변환 가능
# Word start time: 1.496s -> Start frame: 45
# Word end time: 3.178s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0621_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0578_REAL09_F.csv' 변환 가능
# Word start time: 1.272s -> Start frame: 38
# Word end time: 3.44s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0578_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0130_REAL09_F.csv' 변환 가능
# Word start time: 1.632s -> Start frame: 49
# Word end time: 3.577s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0130_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0919_REAL09_F.csv' 변환 가능
# Word start time: 2.25s -> Start frame: 68
# Word end time: 2.943s -> End frame: 88
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0919_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0502_REAL09_F.csv' 변환 가능
# Word start time: 1.335s -> Start frame: 40
# Word end time: 3.245s -> End frame: 97
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0502_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0067_REAL09_F.csv' 변환 가능
# Word start time: 2.074s -> Start frame: 62
# Word end time: 3.662s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0067_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0566_REAL09_F.csv' 변환 가능
# Word start time: 1.5s -> Start frame: 45
# Word end time: 2.502s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0566_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0922_REAL09_F.csv' 변환 가능
# Word start time: 2.283s -> Start frame: 68
# Word end time: 3.168s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0922_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0515_REAL09_F.csv' 변환 가능
# Word start time: 1.366s -> Start frame: 41
# Word end time: 3.384s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0515_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0414_REAL09_F.csv' 변환 가능
# Word start time: 1.391s -> Start frame: 42
# Word end time: 3.159s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0414_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0235_REAL09_F.csv' 변환 가능
# Word start time: 1.927s -> Start frame: 58
# Word end time: 3.573s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0235_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0348_REAL09_F.csv' 변환 가능
# Word start time: 1.319s -> Start frame: 40
# Word end time: 3.545s -> End frame: 106
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0348_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1448_REAL09_F.csv' 변환 가능
# Word start time: 1.405s -> Start frame: 42
# Word end time: 3.117s -> End frame: 94
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1448_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0726_REAL09_F.csv' 변환 가능
# Word start time: 1.506s -> Start frame: 45
# Word end time: 3.703s -> End frame: 111
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0726_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1267_REAL09_F.csv' 변환 가능
# Word start time: 1.352s -> Start frame: 41
# Word end time: 2.176s -> End frame: 65
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1267_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0070_REAL09_F.csv' 변환 가능
# Word start time: 2.388s -> Start frame: 72
# Word end time: 4.588s -> End frame: 138
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0070_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0226_REAL09_F.csv' 변환 가능
# Word start time: 1.033s -> Start frame: 31
# Word end time: 2.509s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0226_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0251_REAL09_F.csv' 변환 가능
# Word start time: 1.551s -> Start frame: 47
# Word end time: 2.688s -> End frame: 81
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0251_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1009_REAL09_F.csv' 변환 가능
# Word start time: 1.36s -> Start frame: 41
# Word end time: 4.275s -> End frame: 128
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1009_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0408_REAL09_F.csv' 변환 가능
# Word start time: 1.319s -> Start frame: 40
# Word end time: 3.229s -> End frame: 97
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0408_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0469_REAL09_F.csv' 변환 가능
# Word start time: 1.314s -> Start frame: 39
# Word end time: 3.516s -> End frame: 105
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0469_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1043_REAL09_F.csv' 변환 가능
# Word start time: 1.54s -> Start frame: 46
# Word end time: 2.978s -> End frame: 89
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1043_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0194_REAL09_F.csv' 변환 가능
# Word start time: 1.399s -> Start frame: 42
# Word end time: 2.888s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0194_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0768_REAL09_F.csv' 변환 가능
# Word start time: 1.243s -> Start frame: 37
# Word end time: 3.284s -> End frame: 99
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0768_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0362_REAL09_F.csv' 변환 가능
# Word start time: 1.514s -> Start frame: 45
# Word end time: 3.604s -> End frame: 108
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0362_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0418_REAL09_F.csv' 변환 가능
# Word start time: 1.44s -> Start frame: 43
# Word end time: 3.552s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0418_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0338_REAL09_F.csv' 변환 가능
# Word start time: 1.53s -> Start frame: 46
# Word end time: 2.968s -> End frame: 89
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0338_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0659_REAL09_F.csv' 변환 가능
# Word start time: 1.368s -> Start frame: 41
# Word end time: 3.623s -> End frame: 109
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0659_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0019_REAL09_F.csv' 변환 가능
# Word start time: 1.611s -> Start frame: 48
# Word end time: 3.087s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0019_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0506_REAL09_F.csv' 변환 가능
# Word start time: 1.108s -> Start frame: 33
# Word end time: 2.8s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0506_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0191_REAL09_F.csv' 변환 가능
# Word start time: 1.755s -> Start frame: 53
# Word end time: 3.335s -> End frame: 100
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0191_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1002_REAL09_F.csv' 변환 가능
# Word start time: 1.29s -> Start frame: 39
# Word end time: 2.37s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1002_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1215_REAL09_F.csv' 변환 가능
# Word start time: 1.439s -> Start frame: 43
# Word end time: 2.175s -> End frame: 65
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1215_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0709_REAL09_F.csv' 변환 가능
# Word start time: 1.585s -> Start frame: 48
# Word end time: 3.388s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0709_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1276_REAL09_F.csv' 변환 가능
# Word start time: 1.234s -> Start frame: 37
# Word end time: 2.146s -> End frame: 64
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1276_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0484_REAL09_F.csv' 변환 가능
# Word start time: 1.31s -> Start frame: 39
# Word end time: 2.996s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0484_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0111_REAL09_F.csv' 변환 가능
# Word start time: 1.534s -> Start frame: 46
# Word end time: 2.893s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0111_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1141_REAL09_F.csv' 변환 가능
# Word start time: 1.281s -> Start frame: 38
# Word end time: 2.095s -> End frame: 63
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1141_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0376_REAL09_F.csv' 변환 가능
# Word start time: 1.493s -> Start frame: 45
# Word end time: 4.077s -> End frame: 122
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0376_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1327_REAL09_F.csv' 변환 가능
# Word start time: 1.539s -> Start frame: 46
# Word end time: 2.365s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1327_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0245_REAL09_F.csv' 변환 가능
# Word start time: 1.266s -> Start frame: 38
# Word end time: 2.859s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0245_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0698_REAL09_F.csv' 변환 가능
# Word start time: 1.331s -> Start frame: 40
# Word end time: 2.991s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0698_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0565_REAL09_F.csv' 변환 가능
# Word start time: 1.505s -> Start frame: 45
# Word end time: 4.153s -> End frame: 125
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0565_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0588_REAL09_F.csv' 변환 가능
# Word start time: 1.414s -> Start frame: 42
# Word end time: 2.745s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0588_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0982_REAL09_F.csv' 변환 가능
# Word start time: 2.508s -> Start frame: 75
# Word end time: 3.767s -> End frame: 113
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0982_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0473_REAL09_F.csv' 변환 가능
# Word start time: 1.618s -> Start frame: 49
# Word end time: 3.401s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0473_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0952_REAL09_F.csv' 변환 가능
# Word start time: 3.478s -> Start frame: 104
# Word end time: 5.052s -> End frame: 152
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0952_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1064_REAL09_F.csv' 변환 가능
# Word start time: 1.346s -> Start frame: 40
# Word end time: 3.227s -> End frame: 97
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1064_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0422_REAL09_F.csv' 변환 가능
# Word start time: 1.512s -> Start frame: 45
# Word end time: 3.451s -> End frame: 104
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0422_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1005_REAL09_F.csv' 변환 가능
# Word start time: 1.486s -> Start frame: 45
# Word end time: 3.518s -> End frame: 106
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1005_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0150_REAL09_F.csv' 변환 가능
# Word start time: 1.576s -> Start frame: 47
# Word end time: 3.245s -> End frame: 97
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0150_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1259_REAL09_F.csv' 변환 가능
# Word start time: 1.394s -> Start frame: 42
# Word end time: 2.157s -> End frame: 65
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1259_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0752_REAL09_F.csv' 변환 가능
# Word start time: 1.234s -> Start frame: 37
# Word end time: 3.046s -> End frame: 91
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0752_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1288_REAL09_F.csv' 변환 가능
# Word start time: 1.416s -> Start frame: 42
# Word end time: 2.402s -> End frame: 72
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1288_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0173_REAL09_F.csv' 변환 가능
# Word start time: 2.135s -> Start frame: 64
# Word end time: 3.519s -> End frame: 106
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0173_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1190_REAL09_F.csv' 변환 가능
# Word start time: 1.771s -> Start frame: 53
# Word end time: 2.835s -> End frame: 85
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1190_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1345_REAL09_F.csv' 변환 가능
# Word start time: 1.22s -> Start frame: 37
# Word end time: 2.06s -> End frame: 62
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1345_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0077_REAL09_F.csv' 변환 가능
# Word start time: 1.683s -> Start frame: 50
# Word end time: 3.951s -> End frame: 119
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0077_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1487_REAL09_F.csv' 변환 가능
# Word start time: 1.586s -> Start frame: 48
# Word end time: 2.988s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1487_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1453_REAL09_F.csv' 변환 가능
# Word start time: 1.316s -> Start frame: 39
# Word end time: 2.801s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1453_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1171_REAL09_F.csv' 변환 가능
# Word start time: 1.357s -> Start frame: 41
# Word end time: 2.461s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1171_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0057_REAL09_F.csv' 변환 가능
# Word start time: 1.584s -> Start frame: 48
# Word end time: 3.164s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0057_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0702_REAL09_F.csv' 변환 가능
# Word start time: 1.539s -> Start frame: 46
# Word end time: 3.407s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0702_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0747_REAL09_F.csv' 변환 가능
# Word start time: 1.282s -> Start frame: 38
# Word end time: 2.596s -> End frame: 78
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0747_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1360_REAL09_F.csv' 변환 가능
# Word start time: 1.522s -> Start frame: 46
# Word end time: 2.439s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1360_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1081_REAL09_F.csv' 변환 가능
# Word start time: 3.867s -> Start frame: 116
# Word end time: 4.367s -> End frame: 131
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1081_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0989_REAL09_F.csv' 변환 가능
# Word start time: 2.052s -> Start frame: 62
# Word end time: 2.91s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0989_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0375_REAL09_F.csv' 변환 가능
# Word start time: 0.986s -> Start frame: 30
# Word end time: 3.212s -> End frame: 96
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0375_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0721_REAL09_F.csv' 변환 가능
# Word start time: 1.703s -> Start frame: 51
# Word end time: 3.177s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0721_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1326_REAL09_F.csv' 변환 가능
# Word start time: 2.81s -> Start frame: 84
# Word end time: 4.117s -> End frame: 124
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1326_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0139_REAL09_F.csv' 변환 가능
# Word start time: 1.418s -> Start frame: 43
# Word end time: 3.06s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0139_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0541_REAL09_F.csv' 변환 가능
# Word start time: 1.497s -> Start frame: 45
# Word end time: 3.762s -> End frame: 113
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0541_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1358_REAL09_F.csv' 변환 가능
# Word start time: 1.423s -> Start frame: 43
# Word end time: 2.423s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1358_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1088_REAL09_F.csv' 변환 가능
# Word start time: 1.446s -> Start frame: 43
# Word end time: 3.049s -> End frame: 91
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1088_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0352_REAL09_F.csv' 변환 가능
# Word start time: 1.302s -> Start frame: 39
# Word end time: 3.084s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0352_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0646_REAL09_F.csv' 변환 가능
# Word start time: 1.505s -> Start frame: 45
# Word end time: 3.115s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0646_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0722_REAL09_F.csv' 변환 가능
# Word start time: 1.424s -> Start frame: 43
# Word end time: 3.7s -> End frame: 111
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0722_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0939_REAL09_F.csv' 변환 가능
# Word start time: 2.584s -> Start frame: 78
# Word end time: 3.599s -> End frame: 108
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0939_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0968_REAL09_F.csv' 변환 가능
# Word start time: 2.427s -> Start frame: 73
# Word end time: 3.299s -> End frame: 99
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0968_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1139_REAL09_F.csv' 변환 가능
# Word start time: 1.513s -> Start frame: 45
# Word end time: 2.214s -> End frame: 66
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1139_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1044_REAL09_F.csv' 변환 가능
# Word start time: 1.446s -> Start frame: 43
# Word end time: 4.009s -> End frame: 120
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1044_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0450_REAL09_F.csv' 변환 가능
# Word start time: 1.194s -> Start frame: 36
# Word end time: 2.714s -> End frame: 81
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0450_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1202_REAL09_F.csv' 변환 가능
# Word start time: 1.612s -> Start frame: 48
# Word end time: 2.456s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1202_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1188_REAL09_F.csv' 변환 가능
# Word start time: 1.5s -> Start frame: 45
# Word end time: 2.677s -> End frame: 80
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1188_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1412_REAL09_F.csv' 변환 가능
# Word start time: 1.184s -> Start frame: 36
# Word end time: 2.323s -> End frame: 70
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1412_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0671_REAL09_F.csv' 변환 가능
# Word start time: 1.344s -> Start frame: 40
# Word end time: 3.004s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0671_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1144_REAL09_F.csv' 변환 가능
# Word start time: 1.334s -> Start frame: 40
# Word end time: 2.454s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1144_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1098_REAL09_F.csv' 변환 가능
# Word start time: 1.4s -> Start frame: 42
# Word end time: 3.39s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1098_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1411_REAL09_F.csv' 변환 가능
# Word start time: 1.136s -> Start frame: 34
# Word end time: 2.415s -> End frame: 72
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1411_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0962_REAL09_F.csv' 변환 가능
# Word start time: 2.627s -> Start frame: 79
# Word end time: 4.065s -> End frame: 122
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0962_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1103_REAL09_F.csv' 변환 가능
# Word start time: 0.657s -> Start frame: 20
# Word end time: 1.568s -> End frame: 47
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1103_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0737_REAL09_F.csv' 변환 가능
# Word start time: 1.696s -> Start frame: 51
# Word end time: 3.091s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0737_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1079_REAL09_F.csv' 변환 가능
# Word start time: 0.679s -> Start frame: 20
# Word end time: 3.667s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1079_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1314_REAL09_F.csv' 변환 가능
# Word start time: 1.483s -> Start frame: 44
# Word end time: 2.289s -> End frame: 69
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1314_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1265_REAL09_F.csv' 변환 가능
# Word start time: 1.487s -> Start frame: 45
# Word end time: 2.473s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1265_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0168_REAL09_F.csv' 변환 가능
# Word start time: 1.8s -> Start frame: 54
# Word end time: 3.279s -> End frame: 98
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0168_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0249_REAL09_F.csv' 변환 가능
# Word start time: 2.124s -> Start frame: 64
# Word end time: 3.34s -> End frame: 100
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0249_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0048_REAL09_F.csv' 변환 가능
# Word start time: 1.668s -> Start frame: 50
# Word end time: 3.378s -> End frame: 101
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0048_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0623_REAL09_F.csv' 변환 가능
# Word start time: 1.288s -> Start frame: 39
# Word end time: 3.113s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0623_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0357_REAL09_F.csv' 변환 가능
# Word start time: 1.511s -> Start frame: 45
# Word end time: 3.794s -> End frame: 114
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0357_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1344_REAL09_F.csv' 변환 가능
# Word start time: 1.536s -> Start frame: 46
# Word end time: 2.342s -> End frame: 70
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1344_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0051_REAL09_F.csv' 변환 가능
# Word start time: 1.371s -> Start frame: 41
# Word end time: 2.496s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0051_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1086_REAL09_F.csv' 변환 가능
# Word start time: 1.454s -> Start frame: 44
# Word end time: 3.081s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1086_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1263_REAL09_F.csv' 변환 가능
# Word start time: 1.178s -> Start frame: 35
# Word end time: 2.123s -> End frame: 64
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1263_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0877_REAL09_F.csv' 변환 가능
# Word start time: 2.207s -> Start frame: 66
# Word end time: 4.039s -> End frame: 121
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0877_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1452_REAL09_F.csv' 변환 가능
# Word start time: 1.457s -> Start frame: 44
# Word end time: 2.612s -> End frame: 78
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1452_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0524_REAL09_F.csv' 변환 가능
# Word start time: 1.507s -> Start frame: 45
# Word end time: 2.689s -> End frame: 81
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0524_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0871_REAL09_F.csv' 변환 가능
# Word start time: 1.331s -> Start frame: 40
# Word end time: 2.798s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0871_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0866_REAL09_F.csv' 변환 가능
# Word start time: 1.484s -> Start frame: 45
# Word end time: 2.951s -> End frame: 89
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0866_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0335_REAL09_F.csv' 변환 가능
# Word start time: 1.395s -> Start frame: 42
# Word end time: 2.747s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0335_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0076_REAL09_F.csv' 변환 가능
# Word start time: 1.739s -> Start frame: 52
# Word end time: 3.735s -> End frame: 112
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0076_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1153_REAL09_F.csv' 변환 가능
# Word start time: 1.616s -> Start frame: 48
# Word end time: 2.535s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1153_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1321_REAL09_F.csv' 변환 가능
# Word start time: 1.503s -> Start frame: 45
# Word end time: 2.434s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1321_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0262_REAL09_F.csv' 변환 가능
# Word start time: 1.103s -> Start frame: 33
# Word end time: 2.541s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0262_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0910_REAL09_F.csv' 변환 가능
# Word start time: 1.911s -> Start frame: 57
# Word end time: 2.891s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0910_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1248_REAL09_F.csv' 변환 가능
# Word start time: 1.38s -> Start frame: 41
# Word end time: 2.258s -> End frame: 68
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1248_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0399_REAL09_F.csv' 변환 가능
# Word start time: 1.358s -> Start frame: 41
# Word end time: 3.319s -> End frame: 100
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0399_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1150_REAL09_F.csv' 변환 가능
# Word start time: 1.259s -> Start frame: 38
# Word end time: 2.734s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1150_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1461_REAL09_F.csv' 변환 가능
# Word start time: 1.26s -> Start frame: 38
# Word end time: 2.436s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1461_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1241_REAL09_F.csv' 변환 가능
# Word start time: 1.474s -> Start frame: 44
# Word end time: 2.419s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1241_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0847_REAL09_F.csv' 변환 가능
# Word start time: 1.16s -> Start frame: 35
# Word end time: 3.372s -> End frame: 101
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0847_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0250_REAL09_F.csv' 변환 가능
# Word start time: 1.144s -> Start frame: 34
# Word end time: 2.269s -> End frame: 68
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0250_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0978_REAL09_F.csv' 변환 가능
# Word start time: 2.197s -> Start frame: 66
# Word end time: 2.74s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0978_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1156_REAL09_F.csv' 변환 가능
# Word start time: 1.337s -> Start frame: 40
# Word end time: 2.022s -> End frame: 61
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1156_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0873_REAL09_F.csv' 변환 가능
# Word start time: 1.502s -> Start frame: 45
# Word end time: 3.122s -> End frame: 94
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0873_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0916_REAL09_F.csv' 변환 가능
# Word start time: 2.085s -> Start frame: 63
# Word end time: 2.872s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0916_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0530_REAL09_F.csv' 변환 가능
# Word start time: 1.494s -> Start frame: 45
# Word end time: 2.79s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0530_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1410_REAL09_F.csv' 변환 가능
# Word start time: 1.445s -> Start frame: 43
# Word end time: 2.931s -> End frame: 88
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1410_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0715_REAL09_F.csv' 변환 가능
# Word start time: 1.373s -> Start frame: 41
# Word end time: 2.813s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0715_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1235_REAL09_F.csv' 변환 가능
# Word start time: 1.701s -> Start frame: 51
# Word end time: 2.424s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1235_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1223_REAL09_F.csv' 변환 가능
# Word start time: 1.545s -> Start frame: 46
# Word end time: 2.538s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1223_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0463_REAL09_F.csv' 변환 가능
# Word start time: 1.342s -> Start frame: 40
# Word end time: 2.902s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0463_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0899_REAL09_F.csv' 변환 가능
# Word start time: 1.725s -> Start frame: 52
# Word end time: 3.013s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0899_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1024_REAL09_F.csv' 변환 가능
# Word start time: 1.287s -> Start frame: 39
# Word end time: 3.606s -> End frame: 108
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1024_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1420_REAL09_F.csv' 변환 가능
# Word start time: 1.309s -> Start frame: 39
# Word end time: 3.057s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1420_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0526_REAL09_F.csv' 변환 가능
# Word start time: 1.339s -> Start frame: 40
# Word end time: 2.773s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0526_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0930_REAL09_F.csv' 변환 가능
# Word start time: 2.587s -> Start frame: 78
# Word end time: 3.509s -> End frame: 105
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0930_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0202_REAL09_F.csv' 변환 가능
# Word start time: 1.175s -> Start frame: 35
# Word end time: 2.729s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0202_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0879_REAL09_F.csv' 변환 가능
# Word start time: 2.159s -> Start frame: 65
# Word end time: 3.583s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0879_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0156_REAL09_F.csv' 변환 가능
# Word start time: 1.141s -> Start frame: 34
# Word end time: 2.729s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0156_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0869_REAL09_F.csv' 변환 가능
# Word start time: 1.769s -> Start frame: 53
# Word end time: 3.15s -> End frame: 94
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0869_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1071_REAL09_F.csv' 변환 가능
# Word start time: 1.797s -> Start frame: 54
# Word end time: 3.985s -> End frame: 120
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1071_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0511_REAL09_F.csv' 변환 가능
# Word start time: 1.358s -> Start frame: 41
# Word end time: 3.72s -> End frame: 112
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0511_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0401_REAL09_F.csv' 변환 가능
# Word start time: 1.294s -> Start frame: 39
# Word end time: 3.14s -> End frame: 94
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0401_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0580_REAL09_F.csv' 변환 가능
# Word start time: 1.36s -> Start frame: 41
# Word end time: 3.099s -> End frame: 93
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0580_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1275_REAL09_F.csv' 변환 가능
# Word start time: 1.524s -> Start frame: 46
# Word end time: 2.55s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1275_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1206_REAL09_F.csv' 변환 가능
# Word start time: 1.522s -> Start frame: 46
# Word end time: 2.258s -> End frame: 68
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1206_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1004_REAL09_F.csv' 변환 가능
# Word start time: 1.436s -> Start frame: 43
# Word end time: 4.392s -> End frame: 132
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1004_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0697_REAL09_F.csv' 변환 가능
# Word start time: 1.268s -> Start frame: 38
# Word end time: 2.993s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0697_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0445_REAL09_F.csv' 변환 가능
# Word start time: 1.513s -> Start frame: 45
# Word end time: 3.01s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0445_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0239_REAL09_F.csv' 변환 가능
# Word start time: 1.829s -> Start frame: 55
# Word end time: 3.436s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0239_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0883_REAL09_F.csv' 변환 가능
# Word start time: 2.482s -> Start frame: 74
# Word end time: 4.858s -> End frame: 146
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0883_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0230_REAL09_F.csv' 변환 가능
# Word start time: 1.297s -> Start frame: 39
# Word end time: 2.631s -> End frame: 79
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0230_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0734_REAL09_F.csv' 변환 가능
# Word start time: 1.495s -> Start frame: 45
# Word end time: 3.191s -> End frame: 96
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0734_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1464_REAL09_F.csv' 변환 가능
# Word start time: 1.494s -> Start frame: 45
# Word end time: 2.546s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1464_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0411_REAL09_F.csv' 변환 가능
# Word start time: 1.269s -> Start frame: 38
# Word end time: 3.037s -> End frame: 91
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0411_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0708_REAL09_F.csv' 변환 가능
# Word start time: 1.518s -> Start frame: 46
# Word end time: 3.407s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0708_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1133_REAL09_F.csv' 변환 가능
# Word start time: 1.859s -> Start frame: 56
# Word end time: 2.882s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1133_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0164_REAL09_F.csv' 변환 가능
# Word start time: 1.993s -> Start frame: 60
# Word end time: 5.362s -> End frame: 161
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0164_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1418_REAL09_F.csv' 변환 가능
# Word start time: 1.342s -> Start frame: 40
# Word end time: 2.77s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1418_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0979_REAL09_F.csv' 변환 가능
# Word start time: 2.382s -> Start frame: 71
# Word end time: 3.154s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0979_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0346_REAL09_F.csv' 변환 가능
# Word start time: 1.615s -> Start frame: 48
# Word end time: 3.49s -> End frame: 105
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0346_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0034_REAL09_F.csv' 변환 가능
# Word start time: 2.186s -> Start frame: 66
# Word end time: 3.74s -> End frame: 112
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0034_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0252_REAL09_F.csv' 변환 가능
# Word start time: 1.699s -> Start frame: 51
# Word end time: 3.889s -> End frame: 117
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0252_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1397_REAL09_F.csv' 변환 가능
# Word start time: 1.415s -> Start frame: 42
# Word end time: 2.554s -> End frame: 77
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1397_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1249_REAL09_F.csv' 변환 가능
# Word start time: 1.554s -> Start frame: 47
# Word end time: 2.479s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1249_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1318_REAL09_F.csv' 변환 가능
# Word start time: 1.435s -> Start frame: 43
# Word end time: 2.296s -> End frame: 69
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1318_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1454_REAL09_F.csv' 변환 가능
# Word start time: 1.311s -> Start frame: 39
# Word end time: 2.213s -> End frame: 66
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1454_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0309_REAL09_F.csv' 변환 가능
# Word start time: 1.731s -> Start frame: 52
# Word end time: 3.012s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0309_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1186_REAL09_F.csv' 변환 가능
# Word start time: 1.353s -> Start frame: 41
# Word end time: 2.352s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1186_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1311_REAL09_F.csv' 변환 가능
# Word start time: 1.597s -> Start frame: 48
# Word end time: 2.382s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1311_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1164_REAL09_F.csv' 변환 가능
# Word start time: 1.014s -> Start frame: 30
# Word end time: 2.456s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1164_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0629_REAL09_F.csv' 변환 가능
# Word start time: 1.197s -> Start frame: 36
# Word end time: 3.301s -> End frame: 99
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0629_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1437_REAL09_F.csv' 변환 가능
# Word start time: 1.274s -> Start frame: 38
# Word end time: 3.372s -> End frame: 101
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1437_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0279_REAL09_F.csv' 변환 가능
# Word start time: 2.759s -> Start frame: 83
# Word end time: 3.932s -> End frame: 118
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0279_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0052_REAL09_F.csv' 변환 가능
# Word start time: 1.831s -> Start frame: 55
# Word end time: 3.542s -> End frame: 106
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0052_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0505_REAL09_F.csv' 변환 가능
# Word start time: 1.346s -> Start frame: 40
# Word end time: 2.511s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0505_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0956_REAL09_F.csv' 변환 가능
# Word start time: 2.581s -> Start frame: 77
# Word end time: 3.353s -> End frame: 101
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0956_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0165_REAL09_F.csv' 변환 가능
# Word start time: 1.862s -> Start frame: 56
# Word end time: 3.477s -> End frame: 104
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0165_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0712_REAL09_F.csv' 변환 가능
# Word start time: 0.902s -> Start frame: 27
# Word end time: 2.634s -> End frame: 79
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0712_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0321_REAL09_F.csv' 변환 가능
# Word start time: 2.14s -> Start frame: 64
# Word end time: 3.342s -> End frame: 100
# ...
# Word end time: 3.42s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0187_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0342_REAL09_F.csv' 변환 가능
# Word start time: 1.499s -> Start frame: 45
# Word end time: 2.808s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0342_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1168_REAL09_F.csv' 변환 가능
# Word start time: 1.281s -> Start frame: 38
# Word end time: 2.208s -> End frame: 66
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1168_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0412_REAL09_F.csv' 변환 가능
# Word start time: 1.415s -> Start frame: 42
# Word end time: 3.434s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0412_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0596_REAL09_F.csv' 변환 가능
# Word start time: 1.316s -> Start frame: 39
# Word end time: 2.826s -> End frame: 85
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0596_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0838_REAL09_F.csv' 변환 가능
# Word start time: 1.38s -> Start frame: 41
# Word end time: 2.954s -> End frame: 89
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0838_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1406_REAL09_F.csv' 변환 가능
# Word start time: 1.317s -> Start frame: 40
# Word end time: 2.768s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1406_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0970_REAL09_F.csv' 변환 가능
# Word start time: 2.621s -> Start frame: 79
# Word end time: 3.4s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0970_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0214_REAL09_F.csv' 변환 가능
# Word start time: 1.51s -> Start frame: 45
# Word end time: 2.739s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0214_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1483_REAL09_F.csv' 변환 가능
# Word start time: 1.288s -> Start frame: 39
# Word end time: 2.484s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1483_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0027_REAL09_F.csv' 변환 가능
# Word start time: 2.362s -> Start frame: 71
# Word end time: 4.047s -> End frame: 121
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0027_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0109_REAL09_F.csv' 변환 가능
# Word start time: 0.75s -> Start frame: 22
# Word end time: 1.862s -> End frame: 56
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0109_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1130_REAL09_F.csv' 변환 가능
# Word start time: 1.487s -> Start frame: 45
# Word end time: 2.535s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1130_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0653_REAL09_F.csv' 변환 가능
# Word start time: 1.373s -> Start frame: 41
# Word end time: 3.656s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0653_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0240_REAL09_F.csv' 변환 가능
# Word start time: 2.43s -> Start frame: 73
# Word end time: 4.102s -> End frame: 123
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0240_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0949_REAL09_F.csv' 변환 가능
# Word start time: 2.56s -> Start frame: 77
# Word end time: 3.578s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0949_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1031_REAL09_F.csv' 변환 가능
# Word start time: 1.476s -> Start frame: 44
# Word end time: 3.007s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1031_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0361_REAL09_F.csv' 변환 가능
# Word start time: 1.508s -> Start frame: 45
# Word end time: 3.254s -> End frame: 98
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0361_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0493_REAL09_F.csv' 변환 가능
# Word start time: 1.127s -> Start frame: 34
# Word end time: 3.323s -> End frame: 100
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0493_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0645_REAL09_F.csv' 변환 가능
# Word start time: 1.275s -> Start frame: 38
# Word end time: 2.677s -> End frame: 80
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0645_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1016_REAL09_F.csv' 변환 가능
# Word start time: 1.437s -> Start frame: 43
# Word end time: 3.448s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1016_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0585_REAL09_F.csv' 변환 가능
# Word start time: 1.493s -> Start frame: 45
# Word end time: 2.294s -> End frame: 69
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0585_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0196_REAL09_F.csv' 변환 가능
# Word start time: 2.068s -> Start frame: 62
# Word end time: 4.547s -> End frame: 136
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0196_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1161_REAL09_F.csv' 변환 가능
# Word start time: 1.305s -> Start frame: 39
# Word end time: 2.151s -> End frame: 65
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1161_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1176_REAL09_F.csv' 변환 가능
# Word start time: 1.39s -> Start frame: 42
# Word end time: 2.405s -> End frame: 72
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1176_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0125_REAL09_F.csv' 변환 가능
# Word start time: 1.739s -> Start frame: 52
# Word end time: 3.671s -> End frame: 110
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0125_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0592_REAL09_F.csv' 변환 가능
# Word start time: 1.367s -> Start frame: 41
# Word end time: 2.733s -> End frame: 82
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0592_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0281_REAL09_F.csv' 변환 가능
# Word start time: 2.522s -> Start frame: 76
# Word end time: 4.755s -> End frame: 143
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0281_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0893_REAL09_F.csv' 변환 가능
# Word start time: 1.823s -> Start frame: 55
# Word end time: 3.296s -> End frame: 99
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0893_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1273_REAL09_F.csv' 변환 가능
# Word start time: 1.422s -> Start frame: 43
# Word end time: 2.354s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1273_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0216_REAL09_F.csv' 변환 가능
# Word start time: 1.169s -> Start frame: 35
# Word end time: 2.802s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0216_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0466_REAL09_F.csv' 변환 가능
# Word start time: 1.219s -> Start frame: 37
# Word end time: 2.785s -> End frame: 84
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0466_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0924_REAL09_F.csv' 변환 가능
# Word start time: 2.316s -> Start frame: 69
# Word end time: 3.082s -> End frame: 92
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0924_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1108_REAL09_F.csv' 변환 가능
# Word start time: 1.67s -> Start frame: 50
# Word end time: 2.758s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1108_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0311_REAL09_F.csv' 변환 가능
# Word start time: 1.488s -> Start frame: 45
# Word end time: 2.869s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0311_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0544_REAL09_F.csv' 변환 가능
# Word start time: 1.51s -> Start frame: 45
# Word end time: 3.419s -> End frame: 103
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0544_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0806_REAL09_F.csv' 변환 가능
# Word start time: 1.051s -> Start frame: 32
# Word end time: 2.998s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0806_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0555_REAL09_F.csv' 변환 가능
# Word start time: 1.251s -> Start frame: 38
# Word end time: 2.874s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0555_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1240_REAL09_F.csv' 변환 가능
# Word start time: 1.35s -> Start frame: 40
# Word end time: 2.059s -> End frame: 62
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1240_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1228_REAL09_F.csv' 변환 가능
# Word start time: 1.507s -> Start frame: 45
# Word end time: 2.358s -> End frame: 71
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1228_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1308_REAL09_F.csv' 변환 가능
# Word start time: 1.62s -> Start frame: 49
# Word end time: 2.467s -> End frame: 74
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1308_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0486_REAL09_F.csv' 변환 가능
# Word start time: 1.326s -> Start frame: 40
# Word end time: 3.035s -> End frame: 91
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0486_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0268_REAL09_F.csv' 변환 가능
# Word start time: 2.107s -> Start frame: 63
# Word end time: 3.953s -> End frame: 119
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0268_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1131_REAL09_F.csv' 변환 가능
# Word start time: 1.538s -> Start frame: 46
# Word end time: 2.658s -> End frame: 80
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1131_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0652_REAL09_F.csv' 변환 가능
# Word start time: 1.478s -> Start frame: 44
# Word end time: 2.751s -> End frame: 83
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0652_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0364_REAL09_F.csv' 변환 가능
# Word start time: 1.456s -> Start frame: 44
# Word end time: 3.173s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0364_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0521_REAL09_F.csv' 변환 가능
# Word start time: 1.372s -> Start frame: 41
# Word end time: 2.903s -> End frame: 87
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0521_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0512_REAL09_F.csv' 변환 가능
# Word start time: 1.291s -> Start frame: 39
# Word end time: 3.2s -> End frame: 96
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0512_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0542_REAL09_F.csv' 변환 가능
# Word start time: 1.41s -> Start frame: 42
# Word end time: 3.159s -> End frame: 95
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0542_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0630_REAL09_F.csv' 변환 가능
# Word start time: 1.156s -> Start frame: 35
# Word end time: 2.544s -> End frame: 76
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0630_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0304_REAL09_F.csv' 변환 가능
# Word start time: 2.962s -> Start frame: 89
# Word end time: 3.892s -> End frame: 117
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0304_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0455_REAL09_F.csv' 변환 가능
# Word start time: 1.305s -> Start frame: 39
# Word end time: 2.716s -> End frame: 81
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0455_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1399_REAL09_F.csv' 변환 가능
# Word start time: 1.623s -> Start frame: 49
# Word end time: 2.852s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1399_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0080_REAL09_F.csv' 변환 가능
# Word start time: 1.928s -> Start frame: 58
# Word end time: 4.182s -> End frame: 125
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0080_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0595_REAL09_F.csv' 변환 가능
# Word start time: 1.413s -> Start frame: 42
# Word end time: 2.858s -> End frame: 86
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0595_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1455_REAL09_F.csv' 변환 가능
# Word start time: 1.273s -> Start frame: 38
# Word end time: 2.516s -> End frame: 75
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1455_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1292_REAL09_F.csv' 변환 가능
# Word start time: 1.394s -> Start frame: 42
# Word end time: 2.063s -> End frame: 62
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1292_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0692_REAL09_F.csv' 변환 가능
# Word start time: 1.417s -> Start frame: 43
# Word end time: 3.278s -> End frame: 98
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0692_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0935_REAL09_F.csv' 변환 가능
# Word start time: 3.11s -> Start frame: 93
# Word end time: 4.083s -> End frame: 122
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0935_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0691_REAL09_F.csv' 변환 가능
# Word start time: 1.506s -> Start frame: 45
# Word end time: 3.216s -> End frame: 96
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0691_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0781_REAL09_F.csv' 변환 가능
# Word start time: 0.893s -> Start frame: 27
# Word end time: 3.003s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0781_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0960_REAL09_F.csv' 변환 가능
# Word start time: 2.851s -> Start frame: 86
# Word end time: 4.124s -> End frame: 124
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0960_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0571_REAL09_F.csv' 변환 가능
# Word start time: 1.775s -> Start frame: 53
# Word end time: 3.385s -> End frame: 102
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0571_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0729_REAL09_F.csv' 변환 가능
# Word start time: 1.321s -> Start frame: 40
# Word end time: 3.003s -> End frame: 90
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0729_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0890_REAL09_F.csv' 변환 가능
# Word start time: 2.678s -> Start frame: 80
# Word end time: 3.572s -> End frame: 107
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0890_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD1281_REAL09_F.csv' 변환 가능
# Word start time: 1.23s -> Start frame: 37
# Word end time: 2.445s -> End frame: 73
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD1281_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0151_REAL09_F.csv' 변환 가능
# Word start time: 1.998s -> Start frame: 60
# Word end time: 4.998s -> End frame: 150
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0151_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0882_REAL09_F.csv' 변환 가능
# Word start time: 1.801s -> Start frame: 54
# Word end time: 3.64s -> End frame: 109
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0882_REAL09_F.npz
# 파일명 '/home/j-j13a602/make_dataset/annotation/NIA_SL_WORD0002_REAL09_F.csv' 변환 가능
# Word start time: 2.756s -> Start frame: 83
# Word end time: 4.076s -> End frame: 122
# [SAVED] /home/j-j13a602/make_dataset/npz/NIA_SL_WORD0002_REAL09_F.npz
# 에러 파일 개수: 0
# 변환 성공 파일 개수 (기존 파일 포함): 1498

# %%
# 들어있는 csv 확인하기
npz_dir = project_path + "/npz"

npz_dir_files = [
    os.path.join(npz_dir, f)
    for f in os.listdir(npz_dir)
    if f.lower().endswith(".npz") and re.search(r"real", f, re.IGNORECASE)
]

print("총 좌표 csv 개수:", len(npz_dir_files))
print(npz_dir_files[:3])
# Out:
# 총 좌표 csv 개수: 1498
# ['/home/j-j13a602/make_dataset/npz/NIA_SL_WORD1453_REAL09_F.npz', '/home/j-j13a602/make_dataset/npz/NIA_SL_WORD0317_REAL09_F.npz', '/home/j-j13a602/make_dataset/npz/NIA_SL_WORD1388_REAL09_F.npz']

# %% [markdown]
# # 훈련하려는 데이터 모으기

# %%
total_df = pd.read_csv(project_path + "/dataset_metadata_real1494_person7.csv")

print(total_df.shape)
total_df.head(2)
# Out:
# (10458, 4)
#                        landmarks_file  word_id  person_id word_gloss
# 0  05-1__NIA_SL_WORD0624_REAL05_F.npz      624          5         새집
# 1  05-1__NIA_SL_WORD1272_REAL05_F.npz     1272          5         뽀뽀

# %%
print(total_df.word_gloss.nunique())
total_df.word_gloss.unique()
# Out:
# 1431
# array(['새집', '뽀뽀', '일어나다', ..., '전기기기', '호텔대학교', '어제밤'],
#       shape=(1431,), dtype=object)

# %%
print(total_df.word_id.nunique())
total_df.word_id.unique()
# Out:
# 1494
# array([ 624, 1272, 1273, ..., 1498, 1499, 1500], shape=(1494,))

# %%
# npz로 변환된 것 확인하기
completed_npz_df = pd.DataFrame(npz_dir_files, columns=["file_name"])

completed_npz_df["word_id"] = completed_npz_df["file_name"].apply(lambda x: int(x.split("__")[-1].split("WORD")[-1][:4]))
completed_npz_df["person_id"] = completed_npz_df["file_name"].apply(lambda x: int(x.split("__")[-1].split("REAL")[-1][:2]))

completed_npz_df.head(2)
# Out:
#                                            file_name  word_id  person_id
# 0  /home/j-j13a602/make_dataset/npz/NIA_SL_WORD14...     1453          9
# 1  /home/j-j13a602/make_dataset/npz/NIA_SL_WORD03...      317          9

# %%
completed_npz_df["file_name"] = completed_npz_df["file_name"].apply(lambda x: x.split("/")[-1])

completed_npz_df.head(2)
# Out:
#                       file_name  word_id  person_id
# 0  NIA_SL_WORD1453_REAL09_F.npz     1453          9
# 1  NIA_SL_WORD0317_REAL09_F.npz      317          9

# %%
# completed_npz_df와 real_detail_metadata 비교
# mp4_name이 file_name에 있으면 해당 word_name을 completed_npz_df 에 컬럼으로 넣어준다.

# Extract the base filename without the directory for merging
completed_npz_df['mp4_name'] = completed_npz_df['file_name'].apply(lambda x: Path(x).stem + ".mp4")

# Merge completed_npz_df3 with syn_detail_metadata to get the word_name
real_completed_with_name = pd.merge(
    completed_npz_df,
    real_detail_metadata[['mp4_name', 'word_name']],
    on='mp4_name',
    how='left'
)

# Drop the redundant 'mp4_name' columns
completed_with_name = real_completed_with_name.drop(columns=['mp4_name'])

# Rename the merged DataFrame to completed_npz_df3
completed_npz_df = completed_with_name

print("completed_npz_df with word_name:")
display(completed_npz_df.head())
# Out:
# completed_npz_df with word_name:
#                       file_name  word_id  person_id word_name_x word_name_y
# 0  NIA_SL_WORD1453_REAL09_F.npz     1453          9         NaN         신용산
# 1  NIA_SL_WORD0317_REAL09_F.npz      317          9         NaN          급행
# 2  NIA_SL_WORD1388_REAL09_F.npz     1388          9         NaN         초대3
# 3  NIA_SL_WORD0171_REAL09_F.npz      171          9         NaN          코치
# 4  NIA_SL_WORD0155_REAL09_F.npz      155          9         NaN         여행사

# %%
completed_npz_df.drop(columns=["word_name_x"], inplace=True)
completed_npz_df.rename(columns={"file_name": "landmarks_file", "word_name_y": "word_gloss"}, inplace=True)

print(completed_npz_df.shape)
completed_npz_df.head(2)
# Out:
# (1498, 4)
#                  landmarks_file  word_id  person_id word_gloss
# 0  NIA_SL_WORD1453_REAL09_F.npz     1453          9        신용산
# 1  NIA_SL_WORD0317_REAL09_F.npz      317          9         급행

# %%
person_9 = completed_npz_df[completed_npz_df['word_id'].isin(total_df.word_id.unique().tolist())].copy()

print(person_9.shape)
person_9.head(2)
# Out:
# (1492, 4)
#                  landmarks_file  word_id  person_id word_gloss
# 0  NIA_SL_WORD1453_REAL09_F.npz     1453          9        신용산
# 1  NIA_SL_WORD0317_REAL09_F.npz      317          9         급행

# %%
person_9.word_id.unique()
# Out:
# array([1453,  317, 1388, ...,  354,  892, 1239], shape=(1492,))

# %%
person_13456810 = total_df[total_df["word_id"].isin(person_9.word_id.unique().tolist())].copy()

print(person_13456810)
person_13456810.head(2)
# Out:
#                            landmarks_file  word_id  person_id word_gloss
# 0      05-1__NIA_SL_WORD0624_REAL05_F.npz      624          5         새집
# 1      05-1__NIA_SL_WORD1272_REAL05_F.npz     1272          5         뽀뽀
# 2      05-1__NIA_SL_WORD1273_REAL05_F.npz     1273          5       일어나다
# 3      05-1__NIA_SL_WORD0001_REAL05_F.npz        1          5         고민
# 4      05-1__NIA_SL_WORD0002_REAL05_F.npz        2          5         뻔뻔
# ...                                   ...      ...        ...        ...
# 10453  08-1__NIA_SL_WORD0464_REAL08_F.npz      464          8         단명
# 10454  08-1__NIA_SL_WORD0465_REAL08_F.npz      465          8         단문
# 10455  08-1__NIA_SL_WORD0466_REAL08_F.npz      466          8        능력자
# 10456  08-1__NIA_SL_WORD0467_REAL08_F.npz      467          8        곰방대
# 10457  08-1__NIA_SL_WORD0468_REAL08_F.npz      468          8         담당
#
# [10444 rows x 4 columns]
#                        landmarks_file  word_id  person_id word_gloss
# 0  05-1__NIA_SL_WORD0624_REAL05_F.npz      624          5         새집
# 1  05-1__NIA_SL_WORD1272_REAL05_F.npz     1272          5         뽀뽀

# %%
final_df = pd.concat([person_13456810, person_9])
print(final_df.shape)

final_df.to_csv(project_path + "/dataset_metadata.csv", index=True, encoding="utf-8")
# Out:
# (11936, 4)

# %%
import zipfile

# Define the path and name for the output zip file
output_zip_path = os.path.join(project_path, "dataset_final.zip")
output_csv_path = os.path.join(project_path, "dataset_metadata.csv")

# Create a new zip file in write mode
with zipfile.ZipFile(output_zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Add the metadata CSV file to the zip archive
    zipf.write(output_csv_path, os.path.basename(output_csv_path))

    # Iterate through the list of NPZ file paths and add each NPZ file
    for npz_file_path in person_9.landmarks_file:
        zipf.write(os.path.join(project_path, "npz", npz_file_path), npz_file_path) # Include in a subfolder in the zip

print(f"Zip file created successfully at: {output_zip_path}")
# Out:
# Zip file created successfully at: /home/j-j13a602/make_dataset/dataset_final.zip

# %%
# %pwd
# Out:
# '/home/j-j13a602/make_dataset'

# %%
import os

print("총 데이터셋 개수:", len(os.listdir('/home/j-j13a602/dataset_final')))
# Out:
# 총 데이터셋 개수: 11938

# %%
11938 / 8
# Out:
# 1492.25
