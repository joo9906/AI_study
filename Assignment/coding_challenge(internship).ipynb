# %% [markdown]
# <a href="https://colab.research.google.com/github/joo9906/AI_study/blob/main/coding_challenge(internship).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Challenge: LLM Performance Optimization
#
# ### Overview
# Your task is to enhance the performance of a small language model (e.g. Qwen2.5-0.5B) on mathematical reasoning tasks. You'll have the freedom to explore various optimization techniques while maintaining reproducibility and providing clear documentation of your methodology.
#
# ### Challenge Requirements
# * Improve the model's performance on the GSM8K benchmark using Qwen2.5-0.5B as your foundation model
# * Document your experimental process and methodology thoroughly
# * Ensure your solution is fully reproducible
# * Submit all necessary code, model checkpoints, and documentation
#
# ### Available Optimization Approaches
# You have flexibility in your approach and can explore techniques such as:
# * Fine-tuning strategy optimization
# * Custom architecture modifications
# * Dataset curation and synthesis
# * Hyperparameter optimization
# * Template and tokenizer configuration adjustments
#
# ### Technical Guidelines
# * While our baseline implementation uses liger-kernel, you're welcome to explore alternative optimization methods (e.g., PEFT, spectrum)
# * You can implement custom components such as:
#   * Custom dataset classes
#   * Specialized data collators
#   * Modified training loops
# * You may leverage larger models (>7B) for data synthesis or knowledge distillation
#
# ### Evaluation Criteria
# * Primary metric: GSM8K benchmark performance
#   * Baseline score (Qwen2.5-0.5B-Instruct): 41.6
#   * Evaluation using EleutherAI's lm-evaluation-harness
#
# Note: Even if significant score improvements aren't achieved, strong technical analysis and well-reasoned experimentation will be valued highly.
#
# ### Deliverables
# Required:
# * Complete notebook (ipynb or Google Colab format)
# * Final model weights and tokenizer (shared via HuggingFace Hub)
#
# Optional:
# * Supplementary analysis report (PDF)
# * Additional experimental results and ablation studies

# %%
# !python -m pip install --upgrade pip -q -U
# !pip install -q -U datasets
# !pip install -q -U transformers
# !pip install -q -U trl
# !pip install -q -U bitsandbytes
# !pip install -q -U accelerate
# !pip install -q -U fla                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          sh-attn
# !pip install -q -U liger-kernel
# !pip install -q -U huggingface_hub
# !pip install -q -U vllm
# Out:
# ERROR: Could not find a version that satisfies the requirement fla (from versions: none)
# ERROR: No matching distribution found for fla

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# (Optional) Mount Google Drive, if you are not using Colab, please comment out the code below.
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
drive.mount('/content/drive')
# Out:
# Mounted at /gdrive
# Mounted at /content/drive

# %%
#(Optional) 구글 드라이브를 사용할 경우 아래의 코드를 통해 모델을 캐싱하여 시간을 절약하고 학습 데이터를 드라이브에 저장할 수 있습니다.
# If you're running Jupyter notebook in local, set your local caching directory in `cache_dir`.
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

import os
cache_dir = "/content/drive/MyDrive/huggingface_cache"
os.makedirs(cache_dir, exist_ok=True) # Ensure the directory exists

# %%
model_id = "Qwen/Qwen2.5-0.5B"

local_path = model_id
local_save_path = os.path.join(cache_dir, local_path)

# %%
from huggingface_hub import snapshot_download
import os

def download_model_repo(repo_id, local_dir):
    # Download the whole repository to the specified local directory
    repo_path = snapshot_download(repo_id=repo_id,
                                  cache_dir=local_dir,
                                  local_dir=local_dir,
                                  local_dir_use_symlinks=False)

    print(f"Repository is saved to: {repo_path}")

def main():
    download_model_repo(model_id, local_save_path)
    print()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:832: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Repository is saved to: /content/drive/MyDrive/huggingface_cache/Qwen/Qwen2.5-0.5B

# %%
from datasets import load_dataset

ds = load_dataset("AI-MO/NuminaMath-CoT", split="train")
ds[0]

# %%
# randomly sample 20000 examples
sampled_ds = ds.shuffle(seed=42).select(range(20000))

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model = AutoModelForCausalLM.from_pretrained(
    local_save_path,
    device_map='auto',
    torch_dtype=torch.float16,
    cache_dir=cache_dir)

model.config.use_cache = False
model.config.pretraining_tp = 1

tokenizer = AutoTokenizer.from_pretrained(model_id,
                                          padding_side='left',
                                          truncation_side='left')

# %%
chat_template = "{%- if tools %}\n    {{- '<|im_start|>system\\n' }}\n    {%- if messages[0]['role'] == 'system' %}\n        {{- messages[0]['content'] }}\n    {%- else %}\n        {{- 'You are Alli, created by Allganize. You are a helpful assistant.' }}\n    {%- endif %}\n    {{- \"\\n\\n# Tools\\n\\nYou may call one or more functions to assist with the user query.\\n\\nYou are provided with function signatures within <tools></tools> XML tags:\\n<tools>\" }}\n    {%- for tool in tools %}\n        {{- \"\\n\" }}\n        {{- tool | tojson }}\n    {%- endfor %}\n    {{- \"\\n</tools>\\n\\nFor each function call, return a json object with function name and arguments within <tool_call></tool_call> XML tags:\\n<tool_call>\\n{\\\"name\\\": <function-name>, \\\"arguments\\\": <args-json-object>}\\n</tool_call><|im_end|>\\n\" }}\n{%- else %}\n    {%- if messages[0]['role'] == 'system' %}\n        {{- '<|im_start|>system\\n' + messages[0]['content'] + '<|im_end|>\\n' }}\n    {%- else %}\n        {{- '<|im_start|>system\\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\\n' }}\n    {%- endif %}\n{%- endif %}\n{%- for message in messages %}\n    {%- if (message.role == \"user\") or (message.role == \"system\" and not loop.first) or (message.role == \"assistant\" and not message.tool_calls) %}\n        {{- '<|im_start|>' + message.role + '\\n' + message.content + '<|im_end|>' + '\\n' }}\n    {%- elif message.role == \"assistant\" %}\n        {{- '<|im_start|>' + message.role }}\n        {%- if message.content %}\n            {{- '\\n' + message.content }}\n        {%- endif %}\n        {%- for tool_call in message.tool_calls %}\n            {%- if tool_call.function is defined %}\n                {%- set tool_call = tool_call.function %}\n            {%- endif %}\n            {{- '\\n<tool_call>\\n{\"name\": \"' }}\n            {{- tool_call.name }}\n            {{- '\", \"arguments\": ' }}\n            {{- tool_call.arguments | tojson }}\n            {{- '}\\n</tool_call>' }}\n        {%- endfor %}\n        {{- '<|im_end|>\\n' }}\n    {%- elif message.role == \"tool\" %}\n        {%- if (loop.index0 == 0) or (messages[loop.index0 - 1].role != \"tool\") %}\n            {{- '<|im_start|>user' }}\n        {%- endif %}\n        {{- '\\n<tool_response>\\n' }}\n        {{- message.content }}\n        {{- '\\n</tool_response>' }}\n        {%- if loop.last or (messages[loop.index0 + 1].role != \"tool\") %}\n            {{- '<|im_end|>\\n' }}\n        {%- endif %}\n    {%- endif %}\n{%- endfor %}\n{%- if add_generation_prompt %}\n    {{- '<|im_start|>assistant\\n' }}\n{%- endif %}\n"

tokenizer.chat_template = chat_template
tokenizer.eos_token = "<|im_end|>"
tokenizer.eos_token_id = 151645

model.config.eos_token_id = tokenizer.eos_token_id
model.generation_config.eos_token_id = tokenizer.eos_token_id

# %%
def format_prompt_func(sample):
  sample['text'] = tokenizer.apply_chat_template(sample['messages'], tokenize = False, add_generation_prompt = False)
  return sample['text']

# %%
# sampled_ds = sampled_ds.map(format_prompt_func, num_proc=os.cpu_count())
sampled_ds = sampled_ds.train_test_split(test_size=0.1, seed=42)

# %%
from transformers import TrainingArguments, Trainer
from trl import SFTTrainer, SFTConfig

training_arguments = SFTConfig(
    dataset_text_field='text',
    output_dir=os.path.join(cache_dir, "results"),
    num_train_epochs=1,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",
    save_strategy='epoch',
    eval_steps=0.1,
    logging_steps=10,
    learning_rate=5e-6,
    weight_decay=0.01,
    max_seq_length=2048,
    max_grad_norm=1,
    max_steps=-1,
    warmup_ratio=0.05,
    packing=True,
    lr_scheduler_type="cosine",
    use_liger=True,
)

trainer = SFTTrainer(
    model=model,
    train_dataset=sampled_ds['train'],
    eval_dataset=sampled_ds['test'],
    formatting_func=format_prompt_func,
    args=training_arguments,
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: kuotient (allganize-research). Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>/content/wandb/run-20250116_052501-iba80uku</code>
# Syncing run <strong><a href='https://wandb.ai/allganize-research/huggingface/runs/iba80uku' target="_blank">/content/drive/MyDrive/huggingface_cache/results</a></strong> to <a href='https://wandb.ai/allganize-research/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/allganize-research/huggingface' target="_blank">https://wandb.ai/allganize-research/huggingface</a>
#  View run at <a href='https://wandb.ai/allganize-research/huggingface/runs/iba80uku' target="_blank">https://wandb.ai/allganize-research/huggingface/runs/iba80uku</a>
#     <div>
#
#       <progress value='1189' max='1189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1189/1189 46:46, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.864800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.729400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>3.221600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>3.532300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.397500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.099500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>3.115400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>3.073900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.954600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.089900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.969400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.802700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.911800</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.807400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.777500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.928200</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.856800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.594900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.645500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.719300</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.748800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.844800</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.751700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.695300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.589700</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.772900</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>2.702700</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.772500</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.670900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.833100</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>2.579900</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>2.790200</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>2.742100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>2.514500</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.669200</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>2.581100</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>2.724100</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>2.750800</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>2.785500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.841500</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>2.704200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>2.540000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>2.537200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>2.617100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>2.557000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>2.633400</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>2.760100</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>2.681300</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>2.599300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>2.493100</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>2.783900</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>2.452800</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>2.714600</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>2.594500</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>2.683900</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>2.491400</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>2.528900</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>2.643500</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>2.666900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>2.774200</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>2.537500</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>2.637700</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>2.649100</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>2.578600</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>2.540100</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>2.638000</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>2.629600</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>2.610400</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>2.516100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>2.574300</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>2.438400</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>2.553800</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>2.691900</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>2.641400</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>2.720600</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>2.689100</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>2.631400</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>2.586800</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>2.774600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>2.649600</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>2.543500</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>2.712800</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>2.405300</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>2.577200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>2.746000</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>2.543200</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>2.614800</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>2.596400</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>2.569400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>2.529400</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>2.686700</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>2.554300</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>2.586700</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>2.513500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>2.604000</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>2.742200</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>2.669600</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>2.635000</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>2.544900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.629000</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>2.552000</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>2.534900</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>2.489400</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>2.649000</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>2.710700</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>2.768000</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>2.657100</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>2.617800</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>2.724100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>2.605000</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>2.792000</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>2.681800</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>2.704400</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>2.938900</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>2.743000</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>2.720500</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>2.661900</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>2.610400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1189, training_loss=2.714443173099707, metrics={'train_runtime': 2815.3423, 'train_samples_per_second': 1.689, 'train_steps_per_second': 0.422, 'total_flos': 2.0916184113217536e+16, 'train_loss': 2.714443173099707, 'epoch': 1.0})

# %%
new_model_name = "allganize/qwen0.5b-tech-interview-test" # please specify your own repo/model id
output_dir = os.path.join(cache_dir, new_model_name)

model.config.use_cache = True
model.save_pretrained(output_dir, safe_serialization=True)
tokenizer.save_pretrained(output_dir)
# Out:
# ('/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/tokenizer_config.json',
#  '/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/special_tokens_map.json',
#  '/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/vocab.json',
#  '/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/merges.txt',
#  '/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/added_tokens.json',
#  '/content/drive/MyDrive/huggingface_cache/allganize/qwen0.5b-tech-interview-test/tokenizer.json')

# %%
model.push_to_hub(repo_id=new_model_name, token=True, max_shard_size="5GB", safe_serialization=True)
tokenizer.push_to_hub(repo_id=new_model_name, token=True)
# Out:
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/allganize/qwen0.5b-tech-interview-test/commit/cf56dd41d4433c4693fbd885e5a83e88153be1fa', commit_message='Upload tokenizer', commit_description='', oid='cf56dd41d4433c4693fbd885e5a83e88153be1fa', pr_url=None, repo_url=RepoUrl('https://huggingface.co/allganize/qwen0.5b-tech-interview-test', endpoint='https://huggingface.co', repo_type='model', repo_id='allganize/qwen0.5b-tech-interview-test'), pr_revision=None, pr_num=None)

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# !cd lm-evaluation-harness && pip install -e .
# Out:
# fatal: destination path 'lm-evaluation-harness' already exists and is not an empty directory.
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (1.2.1)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.4.3)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (3.2.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (4.0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (2.10.2)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.14.0)
# Requirement already satisfied: pybind11>=2.6.2 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (2.13.6)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (1.2.1)
# Requirement already satisfied: rouge-score>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.1.2)
# Requirement already satisfied: sacrebleu>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (2.5.1)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (1.6.0)
# Requirement already satisfied: sqlitedict in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (2.1.0)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (2.5.1+cu121)
# Requirement already satisfied: tqdm-multiprocess in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.0.11)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (4.48.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (0.3.8)
# Requirement already satisfied: word2number in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (1.1)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.11/dist-packages (from lm_eval==0.4.7) (10.5.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.7) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (17.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.7) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->lm_eval==0.4.7) (3.11.11)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.7) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.7) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.7) (1.17.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.7) (3.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.7) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.7) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.7) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.7) (5.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.7) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.7) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.7) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->lm_eval==0.4.7) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->lm_eval==0.4.7) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->lm_eval==0.4.7) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.1->lm_eval==0.4.7) (0.21.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines->lm_eval==0.4.7) (24.3.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (75.1.0)
# Requirement already satisfied: DataProperty<2,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (1.1.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (3.2.3)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (1.3.4)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from pytablewriter->lm_eval==0.4.7) (0.1.7)
# Requirement already satisfied: typepy<2,>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.7) (1.3.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.7) (1.18.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.7) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.7) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.7) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.7) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.7) (2024.12.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.7) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.7) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.7) (3.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.7) (8.1.8)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.7) (2024.2)
# Building wheels for collected packages: lm_eval
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.7-0.editable-py3-none-any.whl size=20337 sha256=037e05a32da16e3360f658621612eb2dc04499f4e1cdc7435fb735917ebff222
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ffouvyxv/wheels/84/1c/11/502a8926c958091ff989c1ae74d66aade33728f4ab83f77d87
# Successfully built lm_eval
# Installing collected packages: lm_eval
#   Attempting uninstall: lm_eval
#     Found existing installation: lm_eval 0.4.7
#     Uninstalling lm_eval-0.4.7:
#       Successfully uninstalled lm_eval-0.4.7
# Successfully installed lm_eval-0.4.7

# %%
eval_output_path = os.path.join(cache_dir, "results", "gsm8k")
os.makedirs(eval_output_path, exist_ok=True)

# It takes about 11 minutes on a single A100 40GB GPU (about 100 minutes on a single T4 GPU)
eval_output_path = os.path.join(eval_output_path, "result-original.json")
tasks = "gsm8k"

# eval_cmd = f"""
# lm_eval --model vllm \
#     --model_args pretrained={new_model_name},trust_remote_code=True,dtype=float16 \
#     --tasks {tasks} \
#     --device cuda:0 \
#     --batch_size auto:4 \
#     --output_path {eval_output_path}
# """

eval_cmd = f"""
lm_eval --model vllm \
    --model_args pretrained={new_model_name},trust_remote_code=True,dtype=float16 \
    --tasks {tasks} \
    --device cuda:0 \
    --batch_size auto:4 \
    --output_path {eval_output_path}
"""

# %%
# run an evaluation command
# !{eval_cmd}
# Out:
# 2025-01-16 07:15:25.650449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 07:15:25.678823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 07:15:25.691715: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 07:15:25.859726: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 07:15:27.704358: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-01-16:07:15:33,570 INFO     [__main__.py:284] Verbosity set to INFO
# 2025-01-16:07:15:43,924 INFO     [__main__.py:381] Selected Tasks: ['gsm8k']
# 2025-01-16:07:15:43,927 INFO     [evaluator.py:165] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-01-16:07:15:43,927 INFO     [evaluator.py:202] Initializing vllm model, with arguments: {'pretrained': 'Qwen/Qwen2.5-0.5B-Instruct', 'trust_remote_code': True, 'dtype': 'float16'}
# config.json: 100% 659/659 [00:00<00:00, 5.07MB/s]
# WARNING 01-16 07:15:45 config.py:2276] Casting torch.bfloat16 to torch.float16.
# INFO 01-16 07:15:58 config.py:510] This model supports multiple tasks: {'generate', 'embed', 'reward', 'classify', 'score'}. Defaulting to 'generate'.
# INFO 01-16 07:15:58 llm_engine.py:234] Initializing an LLM engine (v0.6.6.post1) with config: model='Qwen/Qwen2.5-0.5B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-0.5B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=32768, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=1234, served_model_name=Qwen/Qwen2.5-0.5B-Instruct, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output"],"candidate_compile_sizes":[],"compile_sizes":[],"capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 36.8MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 6.71MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 19.7MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 13.7MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.84MB/s]
# INFO 01-16 07:16:02 selector.py:217] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 01-16 07:16:02 selector.py:129] Using XFormers backend.
# INFO 01-16 07:16:03 model_runner.py:1094] Starting to load model Qwen/Qwen2.5-0.5B-Instruct...
# INFO 01-16 07:16:04 weight_utils.py:251] Using model weights format ['*.safetensors']
# model.safetensors: 100% 988M/988M [00:23<00:00, 42.6MB/s]
# INFO 01-16 07:16:27 weight_utils.py:296] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards: 100% 1/1 [00:01<00:00,  1.01s/it]
# INFO 01-16 07:16:29 model_runner.py:1099] Loading model weights took 0.9276 GB
# INFO 01-16 07:16:32 worker.py:241] Memory profiling takes 2.76 seconds
# INFO 01-16 07:16:32 worker.py:241] the current vLLM instance can use total_gpu_memory (14.75GiB) x gpu_memory_utilization (0.90) = 13.27GiB
# INFO 01-16 07:16:32 worker.py:241] model weights take 0.93GiB; non_torch_memory takes 0.11GiB; PyTorch activation peak memory takes 1.44GiB; the rest of the memory reserved for KV Cache is 10.80GiB.
# INFO 01-16 07:16:32 gpu_executor.py:76] # GPU blocks: 58968, # CPU blocks: 21845
# INFO 01-16 07:16:32 gpu_executor.py:80] Maximum concurrency for 32768 tokens per request: 28.79x
# INFO 01-16 07:16:36 model_runner.py:1415] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100% 35/35 [00:29<00:00,  1.20it/s]
# INFO 01-16 07:17:06 model_runner.py:1535] Graph capturing finished in 29 secs, took 0.68 GiB
# INFO 01-16 07:17:06 llm_engine.py:431] init engine (profile, create kv cache, warmup model) took 36.82 seconds
# 2025-01-16:07:17:12,207 INFO     [task.py:417] Building contexts for gsm8k on rank 0...
# 100% 1319/1319 [00:07<00:00, 183.86it/s]
# 2025-01-16:07:17:19,408 INFO     [evaluator.py:513] Running generate_until requests
# Running generate_until requests:   0% 0/1319 [00:00<?, ?it/s]
# Processed prompts:   0% 0/1319 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts:   0% 1/1319 [00:18<6:36:06, 18.03s/it, est. speed input: 74.31 toks/s, output: 1.50 toks/s]
# Processed prompts:   0% 2/1319 [00:19<3:07:29,  8.54s/it, est. speed input: 124.98 toks/s, output: 3.41 toks/s]
# Processed prompts:   0% 3/1319 [00:20<1:50:04,  5.02s/it, est. speed input: 180.29 toks/s, output: 5.49 toks/s]
# Processed prompts:   0% 6/1319 [00:21<40:35,  1.86s/it, est. speed input: 342.58 toks/s, output: 11.92 toks/s]
# Processed prompts:   1% 8/1319 [00:21<25:18,  1.16s/it, est. speed input: 454.07 toks/s, output: 16.55 toks/s]
# Processed prompts:   1% 9/1319 [00:22<22:46,  1.04s/it, est. speed input: 495.95 toks/s, output: 18.51 toks/s]
# Processed prompts:   1% 11/1319 [00:22<15:43,  1.39it/s, est. speed input: 589.07 toks/s, output: 23.09 toks/s]
# Processed prompts:   1% 14/1319 [00:23<10:31,  2.07it/s, est. speed input: 728.33 toks/s, output: 29.97 toks/s]
# Processed prompts:   1% 16/1319 [00:23<09:07,  2.38it/s, est. speed input: 828.08 toks/s, output: 34.42 toks/s]
# Processed prompts:   1% 19/1319 [00:24<06:49,  3.18it/s, est. speed input: 961.86 toks/s, output: 41.60 toks/s]
# Processed prompts:   2% 24/1319 [00:24<04:37,  4.66it/s, est. speed input: 1182.12 toks/s, output: 53.72 toks/s]
# Processed prompts:   2% 27/1319 [00:25<04:09,  5.18it/s, est. speed input: 1304.11 toks/s, output: 60.81 toks/s]
# Processed prompts:   2% 29/1319 [00:25<04:06,  5.23it/s, est. speed input: 1377.28 toks/s, output: 65.34 toks/s]
# Processed prompts:   2% 32/1319 [00:25<03:47,  5.66it/s, est. speed input: 1501.74 toks/s, output: 72.49 toks/s]
# Processed prompts:   3% 33/1319 [00:26<04:12,  5.10it/s, est. speed input: 1530.77 toks/s, output: 74.41 toks/s]
# Processed prompts:   3% 34/1319 [00:26<04:38,  4.62it/s, est. speed input: 1558.18 toks/s, output: 76.36 toks/s]
# Processed prompts:   3% 37/1319 [00:27<04:01,  5.32it/s, est. speed input: 1685.61 toks/s, output: 83.70 toks/s]
# Processed prompts:   3% 40/1319 [00:27<02:57,  7.23it/s, est. speed input: 1810.48 toks/s, output: 91.86 toks/s]
# Processed prompts:   3% 43/1319 [00:27<02:59,  7.09it/s, est. speed input: 1906.78 toks/s, output: 99.01 toks/s]
# Processed prompts:   3% 46/1319 [00:28<03:19,  6.39it/s, est. speed input: 2000.32 toks/s, output: 105.69 toks/s]
# Processed prompts:   4% 51/1319 [00:28<02:52,  7.36it/s, est. speed input: 2196.46 toks/s, output: 118.28 toks/s]
# Processed prompts:   4% 56/1319 [00:28<02:10,  9.71it/s, est. speed input: 2383.75 toks/s, output: 131.94 toks/s]
# Processed prompts:   4% 59/1319 [00:29<02:22,  8.84it/s, est. speed input: 2470.37 toks/s, output: 138.81 toks/s]
# Processed prompts:   5% 61/1319 [00:29<02:08,  9.83it/s, est. speed input: 2544.89 toks/s, output: 144.23 toks/s]
# Processed prompts:   5% 63/1319 [00:29<02:25,  8.61it/s, est. speed input: 2605.53 toks/s, output: 148.56 toks/s]
# Processed prompts:   5% 66/1319 [00:30<02:05,  9.97it/s, est. speed input: 2710.14 toks/s, output: 156.49 toks/s]
# Processed prompts:   6% 74/1319 [00:30<01:55, 10.76it/s, est. speed input: 2961.25 toks/s, output: 174.77 toks/s]
# Processed prompts:   6% 80/1319 [00:31<01:55, 10.72it/s, est. speed input: 3155.53 toks/s, output: 189.25 toks/s]
# Processed prompts:   6% 85/1319 [00:31<02:01, 10.14it/s, est. speed input: 3289.67 toks/s, output: 200.61 toks/s]
# Processed prompts:   7% 88/1319 [00:32<02:12,  9.32it/s, est. speed input: 3367.03 toks/s, output: 206.94 toks/s]
# Processed prompts:   7% 90/1319 [00:32<02:28,  8.28it/s, est. speed input: 3400.09 toks/s, output: 210.57 toks/s]
# Processed prompts:   7% 93/1319 [00:33<02:35,  7.91it/s, est. speed input: 3483.41 toks/s, output: 216.94 toks/s]
# Processed prompts:   7% 98/1319 [00:33<01:59, 10.25it/s, est. speed input: 3645.19 toks/s, output: 230.44 toks/s]
# Processed prompts:   8% 102/1319 [00:33<02:19,  8.73it/s, est. speed input: 3735.31 toks/s, output: 238.35 toks/s]
# Processed prompts:   8% 105/1319 [00:34<01:59, 10.18it/s, est. speed input: 3827.33 toks/s, output: 246.51 toks/s]
# Processed prompts:   8% 109/1319 [00:34<02:07,  9.52it/s, est. speed input: 3916.62 toks/s, output: 255.27 toks/s]
# Processed prompts:   9% 114/1319 [00:35<02:09,  9.30it/s, est. speed input: 4018.43 toks/s, output: 266.45 toks/s]
# Processed prompts:   9% 119/1319 [00:35<02:20,  8.55it/s, est. speed input: 4113.82 toks/s, output: 274.94 toks/s]
# Processed prompts:  81% 1064/1319 [02:16<00:16, 15.31it/s, est. speed input: 8107.58 toks/s, output: 899.00 toks/s]
# Processed prompts:  81% 1066/1319 [02:16<00:18, 13.86it/s, est. speed input: 8105.95 toks/s, output: 898.29 toks/s]
# Processed prompts:  81% 1068/1319 [02:16<00:19, 12.84it/s, est. speed input: 8106.19 toks/s, output: 898.95 toks/s]
# Processed prompts:  81% 1070/1319 [02:16<00:18, 13.74it/s, est. speed input: 8112.78 toks/s, output: 900.35 toks/s]
# Processed prompts:  81% 1072/1319 [02:17<00:16, 14.62it/s, est. speed input: 8120.38 toks/s, output: 903.39 toks/s]
# Processed prompts:  81% 1074/1319 [02:17<00:15, 15.49it/s, est. speed input: 8126.32 toks/s, output: 904.05 toks/s]
# Processed prompts:  82% 1076/1319 [02:17<00:14, 16.33it/s, est. speed input: 8132.46 toks/s, output: 904.87 toks/s]
# Processed prompts:  82% 1078/1319 [02:17<00:14, 16.97it/s, est. speed input: 8139.03 toks/s, output: 906.43 toks/s]
# Processed prompts:  82% 1082/1319 [02:17<00:10, 22.20it/s, est. speed input: 8157.44 toks/s, output: 909.18 toks/s]
# Processed prompts:  82% 1085/1319 [02:17<00:09, 23.67it/s, est. speed input: 8170.04 toks/s, output: 911.72 toks/s]
# Processed prompts:  83% 1089/1319 [02:17<00:08, 27.62it/s, est. speed input: 8187.50 toks/s, output: 913.49 toks/s]
# Processed prompts:  83% 1092/1319 [02:17<00:08, 28.15it/s, est. speed input: 8199.47 toks/s, output: 914.95 toks/s]
# Processed prompts:  83% 1095/1319 [02:17<00:10, 22.16it/s, est. speed input: 8206.16 toks/s, output: 916.87 toks/s]
# Processed prompts:  84% 1103/1319 [02:18<00:07, 29.14it/s, est. speed input: 8242.57 toks/s, output: 921.46 toks/s]
# Processed prompts:  84% 1107/1319 [02:18<00:08, 26.23it/s, est. speed input: 8255.19 toks/s, output: 923.33 toks/s]
# Processed prompts:  84% 1110/1319 [02:18<00:09, 22.53it/s, est. speed input: 8262.12 toks/s, output: 925.25 toks/s]
# Processed prompts:  84% 1113/1319 [02:18<00:10, 20.46it/s, est. speed input: 8269.54 toks/s, output: 927.24 toks/s]
# Processed prompts:  85% 1116/1319 [02:18<00:10, 19.11it/s, est. speed input: 8276.09 toks/s, output: 928.19 toks/s]
# Processed prompts:  85% 1118/1319 [02:19<00:12, 16.60it/s, est. speed input: 8277.60 toks/s, output: 929.25 toks/s]
# Processed prompts:  85% 1122/1319 [02:19<00:10, 18.24it/s, est. speed input: 8289.86 toks/s, output: 930.36 toks/s]
# Processed prompts:  86% 1129/1319 [02:19<00:07, 24.28it/s, est. speed input: 8319.57 toks/s, output: 933.82 toks/s]
# Processed prompts:  86% 1132/1319 [02:19<00:08, 22.21it/s, est. speed input: 8327.26 toks/s, output: 935.51 toks/s]
# Processed prompts:  86% 1135/1319 [02:19<00:08, 20.78it/s, est. speed input: 8335.39 toks/s, output: 937.84 toks/s]
# Processed prompts:  86% 1139/1319 [02:20<00:08, 21.62it/s, est. speed input: 8349.09 toks/s, output: 940.51 toks/s]
# Processed prompts:  94% 1243/1319 [02:23<00:02, 37.08it/s, est. speed input: 8705.37 toks/s, output: 1003.87 toks/s]
# Processed prompts:  95% 1248/1319 [02:23<00:01, 39.08it/s, est. speed input: 8727.94 toks/s, output: 1010.12 toks/s]
# Processed prompts:  95% 1253/1319 [02:23<00:01, 34.90it/s, est. speed input: 8745.15 toks/s, output: 1014.57 toks/s]
# Processed prompts:  95% 1258/1319 [02:24<00:01, 38.14it/s, est. speed input: 8766.19 toks/s, output: 1019.40 toks/s]
# Processed prompts:  96% 1264/1319 [02:24<00:01, 40.88it/s, est. speed input: 8792.43 toks/s, output: 1026.71 toks/s]
# Processed prompts:  96% 1271/1319 [02:24<00:01, 46.62it/s, est. speed input: 8821.88 toks/s, output: 1033.95 toks/s]
# Processed prompts:  97% 1277/1319 [02:24<00:00, 49.25it/s, est. speed input: 8846.96 toks/s, output: 1039.92 toks/s]
# Processed prompts:  97% 1283/1319 [02:24<00:00, 39.84it/s, est. speed input: 8865.42 toks/s, output: 1045.12 toks/s]
# Processed prompts:  98% 1288/1319 [02:24<00:00, 31.26it/s, est. speed input: 8877.07 toks/s, output: 1049.67 toks/s]
# Processed prompts:  98% 1292/1319 [02:25<00:00, 28.33it/s, est. speed input: 8886.66 toks/s, output: 1053.38 toks/s]
# Processed prompts:  98% 1296/1319 [02:25<00:00, 28.85it/s, est. speed input: 8899.89 toks/s, output: 1057.96 toks/s]
# Processed prompts:  99% 1304/1319 [02:25<00:00, 38.00it/s, est. speed input: 8936.06 toks/s, output: 1069.54 toks/s]
# Processed prompts:  99% 1310/1319 [02:25<00:00, 38.09it/s, est. speed input: 8956.16 toks/s, output: 1077.05 toks/s]
# Processed prompts: 100% 1315/1319 [02:25<00:00, 25.91it/s, est. speed input: 8960.40 toks/s, output: 1082.81 toks/s]
# Processed prompts: 100% 1319/1319 [02:25<00:00,  9.04it/s, est. speed input: 8971.78 toks/s, output: 1088.89 toks/s]
# Running generate_until requests: 100% 1319/1319 [02:26<00:00,  9.02it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-01-16:07:19:52,253 INFO     [evaluation_tracker.py:206] Saving results aggregated
# vllm (pretrained=Qwen/Qwen2.5-0.5B-Instruct,trust_remote_code=True,dtype=float16), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: auto:4
# |Tasks|Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
# |-----|------:|----------------|-----:|-----------|---|-----:|---|-----:|
# |gsm8k|      3|flexible-extract|     5|exact_match|↑  |0.3442|±  |0.0131|
# |     |       |strict-match    |     5|exact_match|↑  |0.3169|±  |0.0128|
#
# [rank0]:[W116 07:19:53.558249812 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %%
# Qwen2.5-0.5B-Insruct results for the reference
#vllm (pretrained=Qwen/Qwen2.5-0.5B-Instruct,trust_remote_code=True,dtype=float16), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: auto:4
#|Tasks|Version|     Filter     |n-shot|  Metric   |   |Value |   |Stderr|
#|-----|------:|----------------|-----:|-----------|---|-----:|---|-----:|
#|gsm8k|      3|flexible-extract|     5|exact_match|↑  |0.3442|±  |0.0131|
#|     |       |strict-match    |     5|exact_match|↑  |0.3169|±  |0.0128|
